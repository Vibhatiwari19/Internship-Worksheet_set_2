# %% [markdown]
# ### Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data. This task will be done in following steps:

# %% [markdown]
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the searchbutton.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.
# - Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

# %%
# connecting Webdriver
driver = webdriver.Chrome(r'E:\HP\Desktop\Internship\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="7c1ce5dc8ecb45a91b7d3f6d2750ee8c")>

# %%
# Opening naukri.com
driver.get('https://www.naukri.com/')

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"(/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input)")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,'qsbSubmit')
search.click()

# %%
# Creating empty lists to store job title, job location, company name, experiecne require
job_title =[]
job_location=[]
company_name =[]
experience_required=[]

# %%
# Scarpping Job title from the given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    
    job_title.append(title)

# %%
# Scarpping Job location from the given page
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)

# %%
# Scarpping Company from the given page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
# Scarpping experience required from the given page
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Title':job_title,'Lacation':job_location,'Company Name':company_name, 'Experience Required':experience_required})
df
# Out:
#                                                Title  \
# 0                                       Data Analyst
# 1                                       Data Analyst
# 2                                       Data Analyst
# 3                                       Data Analyst
# 4  Oracle Tax & Treasury PMO Contractor (Data Ana...
# 5          Environmental Sustainability Data Analyst
# 6                                       Data Analyst
# 7                                       Data Analyst
# 8                                       Data Analyst
# 9                              Data Analyst - EdTech
#
#                                             Lacation  \
# 0                                Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2                                Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5  Bangalore/Bengaluru, Kolkata, Mumbai, New Delh...
# ...

# %% [markdown]
# ### Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location,company_name, full job-description. You have to scrape first 10 jobs data.

# %% [markdown]
# This task will be done in following steps:
#
# first get the webpage https://www.naukri.com/
#
# Enter “Data Scientist” in “Skill,Designations,Companies” field and enter “Bangalore” in “enter the location” field.
#
# Then click the search button.
#
# Then scrape the data for the first 10 jobs results you get.
#
# Finally create a dataframe of the scraped data.
#
# Note- 1. All of the above steps have to be done in code. No step is to be done manually.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

# connecting Webdriver
driver = webdriver.Chrome(r'E:\HP\Desktop\Internship\chromedriver.exe')
driver

# Opening naukri.com
url ='https://www.naukri.com/'
driver.get(url)

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"(/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input)")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,'qsbSubmit')
search.click()

# %%
# Creating empty lists to store job title, job location, company name, experiecne require
job_title =[]
job_location=[]
company_name =[]
job_description=[]

# %%
# Scarpping Job title from the given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in title_tags[0:10]:
    title=i.text
    
    job_title.append(title)

# %%
# Scarpping Job location from the given page
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)

# %%
# Scarpping Company from the given page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
# Scarpping Job Description required from the given page
description_tags=driver.find_elements(By.XPATH,'//div[@class="ellipsis job-description"]')
for i in description_tags[0:10]:
    description=i.text
    job_description.append(description)

# %%
print(len(job_title),len(job_location),len(company_name),len(job_description))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company Name':company_name, 'Job Description':job_description})
df
# Out:
#                    Title                                           Lacation  \
# 0  Hexaware Technologies  Bangalore/Bengaluru, Noida, Mumbai, Pune, Chennai
# 1              Accenture  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 2              Accenture  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 3      Fractal Analytics  Bangalore/Bengaluru, Mumbai, Pune, Chennai, Gu...
# 4      Fractal Analytics  Bangalore/Bengaluru, Mumbai, Pune, Chennai, Gu...
# 5      Fractal Analytics  Bangalore/Bengaluru, Mumbai, Pune, Chennai, Gu...
# 6             Persistent  Bangalore/Bengaluru, Kolkata, Mumbai, New Delh...
# 7                   PayU   Hybrid - Bangalore/Bengaluru, Mumbai (All Areas)
# 8                    PwC  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...
# 9                Genpact                                Bangalore/Bengaluru
#
#             Company Name                                    Job Description
# ...

# %% [markdown]
# ### Q3: In this question you have to scrape data using the filters available on thewebpage as shown below: You have to use the location and salary filter. You have to scrape data for “Data Scientist” designation for first 10 job results. You have to scrape the job-title, job-location, company_name, experience_required. The location filter to be used is “Delhi/NCR” . The salary filter to be used is “3-6” lakhs.

# %% [markdown]
# The task will be done as shown in the below steps:
#
# first get the webpage https://www.naukri.com/
#
# Enter “Data Scientist” in “Skill,Designations,Companies” field.
#
# Then click the search button.
#
# Then apply the location filter and salary filter by checking the respective boxes
#
# Then scrape the data for the first 10 jobs results you get.
#
# Finally create a dataframe of the scraped data.
#
# Note- All of the above steps have to be done in code. No step is to be done manually.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

# connecting Webdriver
driver = webdriver.Chrome(r'E:\HP\Desktop\Internship\chromedriver.exe')
driver

# Opening naukri.com
url ='https://www.naukri.com/'
driver.get(url)

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"(/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input)")
location.send_keys('Delhi/NCR')

# %%
search=driver.find_element(By.CLASS_NAME,'qsbSubmit')
search.click()

# %%
# Creating empty lists to store job title, job location, company name, experiecne require
job_title =[]
job_location=[]
company_name =[]
experience1_required=[]

# %% [markdown]
# ##### Scraping job title, job location, company name, experiecne require from Naukri website

# %%
# Scarpping Job title from the given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    
    job_title.append(title)
job_title
# Out:
# ['Data Science Specialist',
#  'Data Scientist',
#  'Sr. Data scientist',
#  'Data Scientist (With Computer Vision Expertise Only)',
#  'Data Scientist',
#  'Job Opportunity with BARC India as Management Trainee',
#  'Junior Data Scientist',
#  'Data Scientist | Permanent WFH/Remote',
#  'Data Scientist- Bangalore',
#  'Data Scientist']

# %%
# Scarpping Job location from the given page
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
job_location
# Out:
# ['Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#  'Temp. WFH - Kochi/Cochin, Kolkata, Hyderabad/Secunderabad, Pune, Ahmedabad, Gurgaon/Gurugram, Chennai, Coimbatore, Bangalore/Bengaluru',
#  'Hybrid - Bangalore/Bengaluru, Mumbai (All Areas)',
#  'Hybrid - Bangalore/Bengaluru(Whitefield)',
#  'Bangalore/Bengaluru',
#  'Mumbai',
#  'Kolkata, Mumbai, New Delhi, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#  'Permanent Remote',
#  'Bangalore/Bengaluru',
#  'Gurgaon/Gurugram, Bangalore/Bengaluru']

# %%
# Scarpping Company from the given page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
company_name
# Out:
# ['Accenture',
#  'Cognizant',
#  'PayU',
#  'Mercedes Benz',
#  'Capgemini',
#  'Broadcast Audience Research Council (BARC)',
#  'Analytos',
#  'Techno Compass Consulting',
#  'Trigent Software',
#  'Blackbuck']

# %%
# Scarpping experience required from the given page
experience1_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience1_tags[0:10]:
    experience1=i.text
    experience1_required.append(experience1)
experience1_required
# Out:
# ['2-4 Yrs',
#  '6-10 Yrs',
#  '1-6 Yrs',
#  '2-6 Yrs',
#  '3-5 Yrs',
#  '0-1 Yrs',
#  '0-2 Yrs',
#  '1-6 Yrs',
#  '3-6 Yrs',
#  '3-7 Yrs']

# %%
print(len(job_title),len(job_location),len(company_name),len(experience1_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company Name':company_name, 'Experience Required':experience1_required})
df
# Out:
#                                                Title  \
# 0                            Data Science Specialist
# 1                                     Data Scientist
# 2                                 Sr. Data scientist
# 3  Data Scientist (With Computer Vision Expertise...
# 4                                     Data Scientist
# 5  Job Opportunity with BARC India as Management ...
# 6                              Junior Data Scientist
# 7              Data Scientist | Permanent WFH/Remote
# 8                          Data Scientist- Bangalore
# 9                                     Data Scientist
#
#                                             Location  \
# 0  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 1  Temp. WFH - Kochi/Cochin, Kolkata, Hyderabad/S...
# 2   Hybrid - Bangalore/Bengaluru, Mumbai (All Areas)
# 3           Hybrid - Bangalore/Bengaluru(Whitefield)
# 4                                Bangalore/Bengaluru
# 5                                             Mumbai
# ...

# %% [markdown]
# ## Q4 : Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:

# %% [markdown]
# 1. Brand
# 2. Product Description
# 3. Price
#     The attributes which you have to scrape is ticked marked in the below image.
#
# To scrape the data you have to go through following steps:
#
# 1. Go to flipkart webpage by url https://www.flipkart.com/
#
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
#
# 3. After that you will reach to a webpage having a lot of sunglasses. From this page you can scrap the required data as usual.
#
# 4. After scraping data from the first page, go to the “Next” Button at the bottom of the page , then click on it.
#
# 5. Now scrape data from this page as usual
#
# 6. Repeat this until you get data for 100 sunglasses.
#
#     Note that all of the above steps have to be done by coding only and not manually.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

#connecting Webdriver
driver = webdriver.Chrome(r'E:\HP\Desktop\Internship\chromedriver.exe')
driver

# Opening flipkart.comcom
url ='https://www.flipkart.com/'
driver.get(url)

# %%
# Creating empty lists to store brand, product description, price
Brand =[]
Product_description=[]
Price =[]

# %%
# Scarpping brand title from the given page
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[0:100]:
    brand=i.text
    
    Brand.append(brand)

# %%
# Scarpping product description from the given page
product_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in product_tags[0:100]:
    product=i.text
    Product_description.append(product)

# %%
# Scarpping Pricefrom the given page
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags[0:100]:
    price=i.text
    Price.append(price)

# %%
# Creating dataframe
df=pd.DataFrame({'Brand':Brand[0:100],'Product_description':Product_description[0:100], 'Price':Price[0:100]})
df
# Out:
#              Brand                                Product_description   Price
# 0     CRYSTAL CART  Polarized, UV Protection, Mirrored, Gradient R...    ₹492
# 1    VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...  ₹1,999
# 2           AISLIN  UV Protection, Gradient Butterfly, Retro Squar...    ₹475
# 3   ROZZETTA CRAFT  UV Protection, Gradient Retro Square Sunglasse...    ₹516
# 4           PIRASO                 UV Protection Oval Sunglasses (54)    ₹239
# ..             ...                                                ...     ...
# 95  ROZZETTA CRAFT  UV Protection, Gradient Retro Square Sunglasse...    ₹366
# 96            IDEE              UV Protection Cat-eye Sunglasses (17)    ₹999
# 97     like future         UV Protection Round Sunglasses (Free Size)    ₹279
# 98  ROZZETTA CRAFT  Polarized, Riding Glasses Sports, Wrap-around ...    ₹492
# 99  ROZZETTA CRAFT   Polarized, UV Protection Aviator Sunglasses (55)    ₹492
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART

# %% [markdown]
# When you will open the above link you will reach to the below shown webpage. As shown in the above page you have to scrape the tick marked attributes. These are
#
# 1. Rating
# 2. Review_summary
# 3. Full review
# -You have to scrape this data for first 100 reviews.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

#connecting Webdriver
driver = webdriver.Chrome(r'E:\HP\Desktop\Internship\chromedriver.exe')
driver

url=" https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART"
driver.get(url)

# %%
Reviews=[]

Rating=[]

FullReviews=[]

# %% [markdown]
# #### Scraping Data

# %%
# Scarpping rating  from the given page
rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags[0:100]:
    rating=i.text
    
    Rating.append(rating)

# %%
# Scarpping Reviews summary from the given page
review_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in review_tags[0:100]:
    review=i.text
    
    Reviews.append(review)

# %%
# Scarpping Full Reviews  from the given page
fullreview_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in fullreview_tags[0:100]:
    fullreview=i.text
    
    FullReviews.append(fullreview)

# %%
# Creating dataframe
df=pd.DataFrame({'Rating':Rating[0:100],'Review Summary':Reviews[0:100], 'Full Review':FullReviews[0:100]})
print('\033[1m'+'Iphone 11 Reviews from Flipkart :'+'\033[0m')
df
# Out:
# Iphone 11 Reviews from Flipkart :
#    Rating         Review Summary  \
# 0       5  Mind-blowing purchase
# 1       5              Excellent
# 2       5          Great product
# 3       5      Terrific purchase
# 4       5  Mind-blowing purchase
# ..    ...                    ...
# 95      5      Terrific purchase
# 96      5  Mind-blowing purchase
# 97      4              Very Good
# 98      5         Simply awesome
# 99      4   Good quality product
#
#                                           Full Review
# 0   Best Quality Product OF iPhone Series , Sound ...
# 1   Amazing camera and feel super machine I am not...
# 2   Well you all know the specifications . One of ...
# 3   The built quality is not very premium.\nThe ba...
# 4   First thanks to Flipkart for this amazing deal...
# ..                                                ...
# 95  Its Very awesome product working and good came...
# 96  This will help you more. See if you are planni...
# ...

# %% [markdown]
# ## Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.

# %% [markdown]
# You have to scrape 3attributes of each sneaker :
#
# 1. Brand
# 2. Product Description
# 3. Price
#
#     As shown in the below image, you have to scrape the tick marked attributes.Also note that all the steps required during scraping should be done through code only and not manually.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

#connecting Webdriver
driver = webdriver.Chrome(r'E:\HP\Desktop\Internship\chromedriver.exe')
driver

url="https://www.flipkart.com"
driver.get(url)

# %%
#creating the empty lists
Brand=[]
Product_description=[]
Price=[]

# %%
 #Scarpping Brand name from the given page
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags[:100]:
    brand=i.text
    
    Brand.append(brand)

# %%
# Scarpping Product description from the given page
product_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in product_tags[:100]:
    product=i.text
    Product_description.append(product)

# %%
# Scarpping price from the given page
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags[:100]:
    price=i.text
    Price.append(price)

# %%
# Creating dataframe
df=pd.DataFrame({'Brand':Brand[0:100],'Product_description':Product_description[0:100], 'Price':Price[0:100]})
df
# Out:
#          Brand                                Product_description Price
# 0       BRUTON      Combo Pack Of 2 Casual Shoes Sneakers For Men  ₹599
# 1        BIRDE  Premium White Sneakers For women Sneakers For ...  ₹299
# 2          SFR  2006 Trenddy Fashion Sporty Casuals Sneakers R...  ₹299
# 3          SFR                                   Sneakers For Men  ₹279
# 4        BIRDE      Combo Pack Of 2 Casual Shoes Sneakers For Men  ₹499
# ..         ...                                                ...   ...
# 95  HIGHLANDER                                   Sneakers For Men  ₹696
# 96    RapidBox                                   Sneakers For Men  ₹571
# 97      BRUTON      Combo Pack Of 2 Casual Shoes Sneakers For Men  ₹599
# 98       asian  SM-162 Black Walking ,Training,Sneakers,Loafer...  ₹499
# 99       Xtoon       Modern Trendy Sneakers boot Sneakers For Men  ₹369
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Q7: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon.Then set CPU Type filter to “Intel Core i7” and “Intel Core i9” as shown in the below image:

# %% [markdown]
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
#
# 1. title
# 2. Ratings
# 3. Price
# -As shown in the below image as the tick marked attributes.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

#connecting Webdriver
driver = webdriver.Chrome(r'E:\HP\Desktop\Internship\chromedriver.exe')
driver

url=" https://www.amazon.in/"
driver.get(url)

# %%
Title=[]
Rating=[]
Price=[]

# %%
# Scarpping  title from the given page
title_tags=driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in title_tags[0:10]:
    title=i.text
    
    Title.append(title)

# %%
# Scarpping  Ratings from the given page
rating_tags=driver.find_elements(By.XPATH,"//div[@class='a-row a-size-small']/span")
for i in rating_tags[:10]:
    rating=i.text
    Rating.append(rating)

# %%
# Scarpping Price from the given page
price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in price_tags[:10]:
    price=i.text
    Price.append(price)

# %%
# Creating dataframe
df=pd.DataFrame({'Title':Title,'Rating':Rating, 'Price':Price})
print('\033[1m'+'10 Laptops  from Amazon with intel core i7 and intel core i9 CPU :'+'\033[0m')
df
# Out:
# 10 Laptops  from Amazon with intel core i7 and intel core i9 CPU :
#                                                Title Rating     Price
# 0  HP Victus Gaming Latest 12th Gen Intel Core i7...           82,990
# 1  ASUS TUF Gaming F15 (2022), 15.6"(39.62 cms) F...    119    94,990
# 2  ASUS Vivobook Pro 16, Intel Core i9 11th Gen, ...           83,990
# 3  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...     71    93,990
# 4  Samsung Galaxy Book2 (NP750) Intel 12th Gen co...           76,990
# 5  ASUS TUF Dash F15, Intel Core i7-12650H 12th G...     26    99,990
# 6  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...           84,490
# 7  Dell G15-5520 Gaming Laptop, Intel i9-12900H, ...    127  1,38,490
# 8  HP Envy x360 12th Gen Intel Core i7-13.3 inch(...         1,13,900
# 9  ASUS Zenbook Pro 14 Duo OLED (2022) Dual Scree...    103  1,49,990

# %% [markdown]
# ## Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.
# The above task will be done in following steps:
# 1. First get the webpagehttps://www.azquotes.com/
# 2. Click on TopQuotes
# 3. Than scrap a) Quote b) Author c) Type Of Quotes

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

#connecting Webdriver
driver = webdriver.Chrome(r'E:\HP\Desktop\Internship\chromedriver.exe')
driver

url="https://www.azquotes.com/"
driver.get(url)

# %%
Quote=[]
Author=[]
Type_Quote=[]

# %%
# Scarpping Quote from the given page
quote_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in quote_tags[0:100]:
    quote=i.text
    Quote.append(quote)

# %%
# Scarpping Autor from the given page
author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tags[0:100]:
    author=i.text
    Author.append(author)

# %%
# Scarpping Type of Quote from the given page
type_quote_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in type_quote_tags[0:100]:
    type_quote=i.text
    Type_Quote.append(type_quote)

# %%
# Creating dataframe
df=pd.DataFrame({'Quote':Quote[0:100],'Author':Author[0:100],'Type of quote':Type_Quote[0:100]})
print('\033[1m'+'Top 100 Quotes of all time :'+'\033[0m')
df
# Out:
# Top 100 Quotes of all time :
#                                                 Quote                Author  \
# 0   The essence of strategy is choosing what not t...        Michael Porter
# 1   One cannot and must not try to erase the past ...            Golda Meir
# 2   Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3   Death is something inevitable. When a man has ...        Nelson Mandela
# 4   You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                ...                   ...
# 95     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 96  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 97  If you think you are too small to make a diffe...            Dalai Lama
# 98  God doesn't require us to succeed, he only req...         Mother Teresa
# 99    Change your thoughts and you change your world.  Norman Vincent Peale
#
# ...

# %% [markdown]
# ## Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpagehttps://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make theDataFrame.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

#connecting Webdriver
driver = webdriver.Chrome(r'E:\HP\Desktop\Internship\chromedriver.exe')
driver

url="https://www.jagranjosh.com/"
driver.get(url)

# %%
gk=driver.find_element(By.XPATH,"/html/body/div/div[1]/div/div[1]/div/div[5]/div/div[1]/header/div[3]/ul/li[9]/a")
gk.click()

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'lxml')
# Beautiful Soup to find all the tables on the page
tables = soup.find_all('table')

# %%
import pandas as pd
df = pd.read_html(str(tables))

# %%
data=df[0]
print('\033[1m'+'Respected  Prime Ministers of India :'+'\033[0m')
data
# Out:
# Respected  Prime Ministers of India :
#     S.N.                        Name     Born-Dead  \
# 0    1.0           Jawahar Lal Nehru   (1889–1964)
# 1    2.0   Gulzarilal Nanda (Acting)   (1898-1998)
# 2    3.0         Lal Bahadur Shastri   (1904–1966)
# 3    4.0  Gulzari Lal Nanda (Acting)   (1898-1998)
# 4    5.0               Indira Gandhi   (1917–1984)
# 5    6.0               Morarji Desai   (1896–1995)
# 6    7.0                Charan Singh   (1902–1987)
# 7    8.0               Indira Gandhi   (1917–1984)
# 8    9.0                Rajiv Gandhi   (1944–1991)
# 9   10.0                 V. P. Singh   (1931–2008)
# 10  11.0             Chandra Shekhar   (1927–2007)
# 11  12.0         P. V. Narasimha Rao   (1921–2004)
# 12  13.0        Atal Bihari Vajpayee  (1924- 2018)
# 13  14.0            H. D. Deve Gowda   (born 1933)
# 14  15.0          Inder Kumar Gujral   (1919–2012)
# 15  16.0        Atal Bihari Vajpayee   (1924-2018)
# 16  17.0              Manmohan Singh   (born 1932)
# ...

# %% [markdown]
# ## Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e. Car name and Price) from https://www.motor1.com/ This task will be done in following steps:
#
# 1. First get the webpagehttps://www.motor1.com/
# 2. Then You have to click on the List option from Dropdown menu on leftside.
# 3. Then click on 50 most expensive carsin the world..
# 4. Then scrap the mentioned data and make the dataframe

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

#connecting Webdriver
driver = webdriver.Chrome(r'E:\HP\Desktop\Internship\chromedriver.exe')
driver

url="https://www.motor1.com/ "
driver.get(url)

# %%
top50=driver.find_element(By.ID,"search_input")
top50.send_keys("50 most expensive cars")

# %%
cl=driver.find_element(By.XPATH,'//button[@class="m1-search-panel-button m1-search-form-button-animate icon-search-svg"]')
cl.click()

# %%
EX=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div/div[1]/div/div/div[2]/div/div[1]/h3/a')
EX.click()

# %%
Car=[]
name=driver.find_elements(By.TAG_NAME,"h3")
for i in name:
    Car.append(i.text)

# %%
print(Car.remove("Most Expensive Cars In The World"))
# Out:
# None

# %%
Price=[]
p=driver.find_elements(By.XPATH,'/html/body/div[3]/div[7]/div[2]/div[1]/div[2]/div[1]/p/strong')
for i in p:
    Price.append((i.text.split("$"))[-1])

# %%
df=pd.DataFrame({"Car Name":Car,"Price":Price})
print('\033[1m'+'Most Expensive Cars in the world :'+'\033[0m')
df
# Out:
# Most Expensive Cars in the world :
#                            Car Name                Price
# 0                     De Tomaso P72          1.3 Million
# 1                 Ferrari LaFerrari          1.4 Million
# 2                     Pagani Huayra          1.4 Million
# 3                      McLaren Elva
# 4                       Czinger 21C          1.7 Million
# 5                     Ferrari Monza          1.7 Million
# 6                Gordon Murray T.33          1.7 Million
# 7                 Koenigsegg Gemera          1.7 Million
# 8                       Zenvo TSR-S          1.7 Million
# 9                Hennessey Venom F5          1.7 Million
# 10                  Bentley Bacalar          1.8 Million
# 11    Hispano Suiza Carmen Boulogne          1.9 Million
# 12           Bentley Mulliner Batur          1.9 Million
# 13                     Deus Vayanne          2.0 Million
# 14                      SSC Tuatara          2.0 Million
# ...
